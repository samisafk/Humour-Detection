# %%
import torch
from transformers import T5ForConditionalGeneration, T5Tokenizer, Trainer, TrainingArguments
from datasets import Dataset
import pandas as pd
import time
import os
import shutil
from torch.utils.data import DataLoader
from tqdm.auto import tqdm
# Out:
# WARNING:tensorflow:From C:\Users\samee\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
class DataProcessor:
    """Handles all data preprocessing and loading operations"""
    
    def __init__(self, tokenizer, max_length=128):
        self.tokenizer = tokenizer
        self.max_length = max_length

    def preprocess_data(self, examples, is_training=True):
        """Preprocesses the data by tokenizing inputs and labels"""
        inputs = [f"classify if this sentence is humorous: {text}" for text in examples['text']]
        targets = examples['label_text']
        
        # Tokenize inputs
        model_inputs = self.tokenizer(
            inputs,
            max_length=self.max_length,
            truncation=True,
            padding="max_length",
            return_tensors="pt"
        )

        if is_training:
            # Tokenize labels
            with self.tokenizer.as_target_tokenizer():
                labels = self.tokenizer(
                    targets,
                    max_length=10,
                    truncation=True,
                    padding="max_length",
                    return_tensors="pt"
                ).input_ids
                labels[labels == self.tokenizer.pad_token_id] = -100
            model_inputs["labels"] = labels

        return model_inputs

    def create_dataloader(self, dataset, batch_size=8, shuffle=True):
        """Creates a DataLoader from the dataset"""
        preprocessed_dataset = Dataset.from_dict({
            'text': dataset['text'],
            'label_text': dataset['label_text']
        })
        
        def collate_fn(examples):
            return self.preprocess_data({
                'text': [ex['text'] for ex in examples],
                'label_text': [ex['label_text'] for ex in examples]
            })
        
        return DataLoader(
            preprocessed_dataset,
            batch_size=batch_size,
            shuffle=shuffle,
            collate_fn=collate_fn
        )

    @staticmethod
    def prepare_dataset(csv_path):
        """Prepares the initial dataset from CSV"""
        data = pd.read_csv(csv_path)
        data.columns = ["text", "label"]
        data['label_text'] = data['label'].apply(lambda x: "humorous" if x == 1 else "not humorous")
        dataset = Dataset.from_pandas(data)
        return dataset.train_test_split(test_size=0.2, seed=42)

# %%
class ModelTrainer:
    """Handles model training and evaluation"""
    
    def __init__(self, model, device):
        self.model = model
        self.device = device
        self.temp_checkpoint_dir = './temp_checkpoint'

    def train(self, train_dataloader, val_dataloader=None, 
              epochs=3, learning_rate=2e-5, save_best_only=True):
        """Trains the model with the given parameters"""
        
        optimizer = torch.optim.AdamW(self.model.parameters(), lr=learning_rate)
        best_loss = float('inf')
        
        # Create temporary checkpoint directory
        os.makedirs(self.temp_checkpoint_dir, exist_ok=True)
        
        print(f"Training on {self.device}")
        
        try:
            for epoch in range(epochs):
                epoch_start = time.time()
                self._train_epoch(train_dataloader, optimizer, epoch, epochs)
                
                # Validation
                if val_dataloader is not None:
                    val_loss = self.evaluate(val_dataloader)
                    print(f"\nEpoch {epoch + 1}: Val Loss = {val_loss:.4f}")
                    
                    if save_best_only and val_loss < best_loss:
                        best_loss = val_loss
                        self._save_checkpoint(epoch, optimizer, best_loss)
                
                print(f"Epoch {epoch + 1} completed in {time.time() - epoch_start:.2f} seconds")

            # Load best model if it exists
            if save_best_only:
                self._load_best_model()
                
        finally:
            # Cleanup
            self._cleanup()

    def _train_epoch(self, train_dataloader, optimizer, epoch, epochs):
        """Trains for one epoch"""
        self.model.train()
        total_loss = 0
        train_progress_bar = tqdm(train_dataloader, desc=f'Epoch {epoch + 1}/{epochs}')
        
        for batch in train_progress_bar:
            batch = {k: v.to(self.device) for k, v in batch.items()}
            
            optimizer.zero_grad()
            outputs = self.model(**batch)
            loss = outputs.loss
            loss.backward()
            optimizer.step()
            
            total_loss += loss.item()
            train_progress_bar.set_postfix({'loss': f'{loss.item():.4f}'})
        
        return total_loss / len(train_dataloader)

    def evaluate(self, val_dataloader):
        """Evaluates the model on validation data"""
        self.model.eval()
        total_loss = 0
        
        with torch.no_grad():
            for batch in val_dataloader:
                batch = {k: v.to(self.device) for k, v in batch.items()}
                outputs = self.model(**batch)
                total_loss += outputs.loss.item()
                
        return total_loss / len(val_dataloader)

    def _save_checkpoint(self, epoch, optimizer, loss):
        """Saves model checkpoint"""
        torch.save({
            'epoch': epoch,
            'model_state_dict': self.model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'loss': loss,
        }, os.path.join(self.temp_checkpoint_dir, 'best_model.pt'))

    def _load_best_model(self):
        """Loads the best model from checkpoint"""
        checkpoint_path = os.path.join(self.temp_checkpoint_dir, 'best_model_for_t5_base.pt')
        if os.path.exists(checkpoint_path):
            checkpoint = torch.load(checkpoint_path)
            self.model.load_state_dict(checkpoint['model_state_dict'])

    def _cleanup(self):
        """Cleans up temporary files"""
        if os.path.exists(self.temp_checkpoint_dir):
            shutil.rmtree(self.temp_checkpoint_dir)

# %%
class Predictor:
    """Handles model prediction"""
    
    def __init__(self, model, tokenizer, device, max_length=128):
        self.model = model
        self.tokenizer = tokenizer
        self.device = device
        self.max_length = max_length

    def predict(self, sentence):
        """Makes a prediction for a single sentence"""
        self.model.eval()
        input_text = f"classify if this sentence is humorous: {sentence}"
        inputs = self.tokenizer(
            input_text,
            return_tensors="pt",
            max_length=self.max_length,
            truncation=True,
            padding="max_length"
        ).to(self.device)
        
        with torch.no_grad():
            outputs = self.model.generate(**inputs)
        
        return self.tokenizer.decode(outputs[0], skip_special_tokens=True)

# %%
if __name__ == "__main__":
    # Initialize common components
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    tokenizer = T5Tokenizer.from_pretrained("t5-base")
    model = T5ForConditionalGeneration.from_pretrained("t5-base").to(device)

    # Initialize the three main components
    data_processor = DataProcessor(tokenizer)
    trainer = ModelTrainer(model, device)
    predictor = Predictor(model, tokenizer, device)

    # Prepare dataset
    dataset = data_processor.prepare_dataset("dataset.csv")
    
    # Create dataloaders
    train_dataloader = data_processor.create_dataloader(dataset['train'], batch_size=8)
    val_dataloader = data_processor.create_dataloader(dataset['test'], batch_size=8, shuffle=False)
    
    # Train the model
    trainer.train(
        train_dataloader,
        val_dataloader,
        epochs=3,
        learning_rate=2e-5,
        save_best_only=True
    )
# Out:
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# C:\Users\samee\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\transformers\tokenization_utils_base.py:1617: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be deprecated in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Training on cuda
# Epoch 1/3:   0%|          | 0/20000 [00:00<?, ?it/s]
# C:\Users\samee\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\transformers\tokenization_utils_base.py:4117: UserWarning: `as_target_tokenizer` is deprecated and will be removed in v5 of Transformers. You can tokenize your labels by using the argument `text_target` of the regular `__call__` method (either in the same call as your input texts if you use the same keyword arguments, or in a separate call.
#   warnings.warn(
# Epoch 1: Val Loss = 0.0132
# Epoch 1 completed in 3738.94 seconds
# Epoch 2/3:   0%|          | 0/20000 [00:00<?, ?it/s]
# Epoch 2: Val Loss = 0.0121
# Epoch 2 completed in 3711.92 seconds
# Epoch 3/3:   0%|          | 0/20000 [00:00<?, ?it/s]
# Epoch 3: Val Loss = 0.0130
# Epoch 3 completed in 3710.42 seconds

# %%
# Make a prediction
test_sentence = "5 reasons the 2016 election feels so personal" 
prediction = predictor.predict(test_sentence)
print(f"\nSentence: '{test_sentence}'\nPrediction: {prediction}")
# Out:
# Sentence: '5 reasons the 2016 election feels so personal'
# Prediction: not humorous
# C:\Users\samee\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\transformers\generation\utils.py:1220: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(

# %%
from sklearn.metrics import classification_report, accuracy_score

def evaluate(model, val_dataloader, device):
    """Evaluates the model on validation data and prints classification metrics."""
    model.eval()
    all_preds = []
    all_labels = []
    
    print("Starting evaluation...")

    with torch.no_grad():
        for i, batch in enumerate(val_dataloader):
            # Move batch to device
            batch = {k: v.to(device) for k, v in batch.items()}
            print(f"Processing batch {i + 1}/{len(val_dataloader)}")

            # Perform forward pass and get logits
            outputs = model(input_ids=batch["input_ids"], attention_mask=batch["attention_mask"], labels=batch["labels"])
            logits = outputs.logits

            # Get the most probable class (0 or 1) for each example
            preds = torch.argmax(logits, dim=-1).cpu().numpy().flatten()

            # Extract the ground truth labels, flatten them, and remove padding labels (-100)
            labels = batch["labels"].cpu().numpy().flatten()
            labels = [label for label in labels if label != -100]  # Keep only valid labels

            # Collect predictions and labels
            all_preds.extend(preds[:len(labels)])  # Ensure preds length matches labels
            all_labels.extend(labels)

    # Debug: Print lengths of all_labels and all_preds
    print(f"Length of all_labels: {len(all_labels)}, Length of all_preds: {len(all_preds)}")

    # Calculate and print classification metrics
    accuracy = accuracy_score(all_labels, all_preds)
    report = classification_report(all_labels, all_preds, target_names=["not humorous", "humorous"])
    
    print(f"\nAccuracy: {accuracy:.4f}")
    print("\nClassification Report:")
    print(report)

    print("Evaluation completed successfully.")

# %%
evaluate(model, val_dataloader, device)
# Out:
# Starting evaluation...
# Processing batch 1/5000
# Processing batch 2/5000
# Processing batch 3/5000
# C:\Users\samee\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\transformers\tokenization_utils_base.py:4117: UserWarning: `as_target_tokenizer` is deprecated and will be removed in v5 of Transformers. You can tokenize your labels by using the argument `text_target` of the regular `__call__` method (either in the same call as your input texts if you use the same keyword arguments, or in a separate call.
#   warnings.warn(
# Processing batch 4/5000
# Processing batch 5/5000
# Processing batch 6/5000
# Processing batch 7/5000
# Processing batch 8/5000
# Processing batch 9/5000
# Processing batch 10/5000
# Processing batch 11/5000
# Processing batch 12/5000
# Processing batch 13/5000
# Processing batch 14/5000
# Processing batch 15/5000
# Processing batch 16/5000
# Processing batch 17/5000
# Processing batch 18/5000
# Processing batch 19/5000
# Processing batch 20/5000
# Processing batch 21/5000
# Processing batch 22/5000
# Processing batch 23/5000
# Processing batch 24/5000
# Processing batch 25/5000
# Processing batch 26/5000
# Processing batch 27/5000
# Processing batch 28/5000
# Processing batch 29/5000
# Processing batch 30/5000
# Processing batch 31/5000
# Processing batch 32/5000
# Processing batch 33/5000
# Processing batch 34/5000
# Processing batch 35/5000
# Processing batch 36/5000
# Processing batch 37/5000
# Processing batch 38/5000
# Processing batch 39/5000
# Processing batch 40/5000
# Processing batch 41/5000
# Processing batch 42/5000
# Processing batch 43/5000
# Processing batch 44/5000
# Processing batch 45/5000
# Processing batch 46/5000
# Processing batch 47/5000
# Processing batch 48/5000
# Processing batch 49/5000
# Processing batch 50/5000
# Processing batch 51/5000
# Processing batch 52/5000
# Processing batch 53/5000
# Processing batch 54/5000
# Processing batch 55/5000
# Processing batch 56/5000
# Processing batch 57/5000
# Processing batch 58/5000
# Processing batch 59/5000
# Processing batch 60/5000
# Processing batch 61/5000
# Processing batch 62/5000
# Processing batch 63/5000
# Processing batch 64/5000
# Processing batch 65/5000
# Processing batch 66/5000
# Processing batch 67/5000
# Processing batch 68/5000
# Processing batch 69/5000
# Processing batch 70/5000
# Processing batch 71/5000
# Processing batch 72/5000
# Processing batch 73/5000
# Processing batch 74/5000
# Processing batch 75/5000
# Processing batch 76/5000
# Processing batch 77/5000
# Processing batch 78/5000
# Processing batch 79/5000
# Processing batch 80/5000
# Processing batch 81/5000
# Processing batch 82/5000
# Processing batch 83/5000
# Processing batch 84/5000
# Processing batch 85/5000
# Processing batch 86/5000
# Processing batch 87/5000
# Processing batch 88/5000
# Processing batch 89/5000
# Processing batch 90/5000
# Processing batch 91/5000
# Processing batch 92/5000
# Processing batch 93/5000
# Processing batch 94/5000
# Processing batch 95/5000
# Processing batch 96/5000
# Processing batch 97/5000
# Processing batch 98/5000
# Processing batch 99/5000
# Processing batch 100/5000
# Processing batch 101/5000
# Processing batch 102/5000
# Processing batch 103/5000
# Processing batch 104/5000
# Processing batch 105/5000
# Processing batch 106/5000
# Processing batch 107/5000
# Processing batch 108/5000
# Processing batch 109/5000
# Processing batch 110/5000
# Processing batch 111/5000
# Processing batch 112/5000
# Processing batch 113/5000
# Processing batch 114/5000
# Processing batch 115/5000
# Processing batch 116/5000
# Processing batch 117/5000
# Processing batch 118/5000
# Processing batch 119/5000
# Processing batch 120/5000
# Processing batch 121/5000
# Processing batch 122/5000
# Processing batch 123/5000
# Processing batch 124/5000
# Processing batch 125/5000
# Processing batch 126/5000
# Processing batch 127/5000
# Processing batch 128/5000
# Processing batch 129/5000
# Processing batch 130/5000
# Processing batch 131/5000
# Processing batch 132/5000
# Processing batch 133/5000
# Processing batch 134/5000
# Processing batch 135/5000
# Processing batch 136/5000
# Processing batch 137/5000
# Processing batch 138/5000
# Processing batch 139/5000
# Processing batch 140/5000
# Processing batch 141/5000
# Processing batch 142/5000
# Processing batch 143/5000
# Processing batch 144/5000
# Processing batch 145/5000
# Processing batch 146/5000
# Processing batch 147/5000
# Processing batch 148/5000
# Processing batch 149/5000
# Processing batch 150/5000
# Processing batch 151/5000
# Processing batch 152/5000
# Processing batch 153/5000
# Processing batch 154/5000
# Processing batch 155/5000
# Processing batch 156/5000
# Processing batch 157/5000
# Processing batch 158/5000
# Processing batch 159/5000
# Processing batch 160/5000
# Processing batch 161/5000
# Processing batch 162/5000
# Processing batch 163/5000
# Processing batch 164/5000
# Processing batch 165/5000
# Processing batch 166/5000
# Processing batch 167/5000
# Processing batch 168/5000
# Processing batch 169/5000
# Processing batch 170/5000
# Processing batch 171/5000
# Processing batch 172/5000
# Processing batch 173/5000
# Processing batch 174/5000
# Processing batch 175/5000
# Processing batch 176/5000
# Processing batch 177/5000
# Processing batch 178/5000
# Processing batch 179/5000
# Processing batch 180/5000
# Processing batch 181/5000
# Processing batch 182/5000
# Processing batch 183/5000
# Processing batch 184/5000
# Processing batch 185/5000
# Processing batch 186/5000
# Processing batch 187/5000
# Processing batch 188/5000
# Processing batch 189/5000
# Processing batch 190/5000
# Processing batch 191/5000
# Processing batch 192/5000
# Processing batch 193/5000
# Processing batch 194/5000
# Processing batch 195/5000
# Processing batch 196/5000
# Processing batch 197/5000
# Processing batch 198/5000
# Processing batch 199/5000
# Processing batch 200/5000
# Processing batch 201/5000
# Processing batch 202/5000
# Processing batch 203/5000
# Processing batch 204/5000
# Processing batch 205/5000
# Processing batch 206/5000
# Processing batch 207/5000
# Processing batch 208/5000
# Processing batch 209/5000
# Processing batch 210/5000
# Processing batch 211/5000
# Processing batch 212/5000
# Processing batch 213/5000
# Processing batch 214/5000
# Processing batch 215/5000
# Processing batch 216/5000
# Processing batch 217/5000
# Processing batch 218/5000
# Processing batch 219/5000
# Processing batch 220/5000
# Processing batch 221/5000
# Processing batch 222/5000
# Processing batch 223/5000
# Processing batch 224/5000
# Processing batch 225/5000
# Processing batch 226/5000
# Processing batch 227/5000
# Processing batch 228/5000
# Processing batch 229/5000
# Processing batch 230/5000
# Processing batch 231/5000
# Processing batch 232/5000
# Processing batch 233/5000
# Processing batch 234/5000
# Processing batch 235/5000
# Processing batch 236/5000
# Processing batch 237/5000
# Processing batch 238/5000
# Processing batch 239/5000
# Processing batch 240/5000
# Processing batch 241/5000
# Processing batch 242/5000
# Processing batch 243/5000
# Processing batch 244/5000
# Processing batch 245/5000
# Processing batch 246/5000
# Processing batch 247/5000
# Processing batch 248/5000
# Processing batch 249/5000
# Processing batch 250/5000
# Processing batch 251/5000
# Processing batch 252/5000
# Processing batch 253/5000
# Processing batch 254/5000
# Processing batch 255/5000
# Processing batch 256/5000
# Processing batch 257/5000
# Processing batch 258/5000
# Processing batch 259/5000
# Processing batch 260/5000
# Processing batch 261/5000
# Processing batch 262/5000
# Processing batch 263/5000
# Processing batch 264/5000
# Processing batch 265/5000
# Processing batch 266/5000
# Processing batch 267/5000
# Processing batch 268/5000
# Processing batch 269/5000
# Processing batch 270/5000
# Processing batch 271/5000
# Processing batch 272/5000
# Processing batch 273/5000
# Processing batch 274/5000
# Processing batch 275/5000
# Processing batch 276/5000
# Processing batch 277/5000
# Processing batch 278/5000
# Processing batch 279/5000
# Processing batch 280/5000
# Processing batch 281/5000
# Processing batch 282/5000
# Processing batch 283/5000
# Processing batch 284/5000
# Processing batch 285/5000
# Processing batch 286/5000
# Processing batch 287/5000
# Processing batch 288/5000
# Processing batch 289/5000
# Processing batch 290/5000
# Processing batch 291/5000
# Processing batch 292/5000
# Processing batch 293/5000
# Processing batch 294/5000
# Processing batch 295/5000
# Processing batch 296/5000
# Processing batch 297/5000
# Processing batch 298/5000
# Processing batch 299/5000
# Processing batch 300/5000
# Processing batch 301/5000
# Processing batch 302/5000
# Processing batch 303/5000
# Processing batch 304/5000
# Processing batch 305/5000
# Processing batch 306/5000
# Processing batch 307/5000
# Processing batch 308/5000
# Processing batch 309/5000
# Processing batch 310/5000
# Processing batch 311/5000
# Processing batch 312/5000
# Processing batch 313/5000
# Processing batch 314/5000
# Processing batch 315/5000
# Processing batch 316/5000
# Processing batch 317/5000
# Processing batch 318/5000
# Processing batch 319/5000
# Processing batch 320/5000
# Processing batch 321/5000
# Processing batch 322/5000
# Processing batch 323/5000
# Processing batch 324/5000
# Processing batch 325/5000
# Processing batch 326/5000
# Processing batch 327/5000
# Processing batch 328/5000
# Processing batch 329/5000
# Processing batch 330/5000
# Processing batch 331/5000
# Processing batch 332/5000
# Processing batch 333/5000
# Processing batch 334/5000
# Processing batch 335/5000
# Processing batch 336/5000
# Processing batch 337/5000
# Processing batch 338/5000
# Processing batch 339/5000
# Processing batch 340/5000
# Processing batch 341/5000
# Processing batch 342/5000
# Processing batch 343/5000
# Processing batch 344/5000
# Processing batch 345/5000
# Processing batch 346/5000
# Processing batch 347/5000
# Processing batch 348/5000
# Processing batch 349/5000
# Processing batch 350/5000
# Processing batch 351/5000
# Processing batch 352/5000
# Processing batch 353/5000
# Processing batch 354/5000
# Processing batch 355/5000
# Processing batch 356/5000
# Processing batch 357/5000
# Processing batch 358/5000
# Processing batch 359/5000
# Processing batch 360/5000
# Processing batch 361/5000
# Processing batch 362/5000
# Processing batch 363/5000
# Processing batch 364/5000
# Processing batch 365/5000
# Processing batch 366/5000
# Processing batch 367/5000
# Processing batch 368/5000
# Processing batch 369/5000
# Processing batch 370/5000
# Processing batch 371/5000
# Processing batch 372/5000
# Processing batch 373/5000
# Processing batch 374/5000
# Processing batch 375/5000
# Processing batch 376/5000
# Processing batch 377/5000
# Processing batch 378/5000
# Processing batch 379/5000
# Processing batch 380/5000
# Processing batch 381/5000
# Processing batch 382/5000
# Processing batch 383/5000
# Processing batch 384/5000
# Processing batch 385/5000
# Processing batch 386/5000
# Processing batch 387/5000
# Processing batch 388/5000
# Processing batch 389/5000
# Processing batch 390/5000
# Processing batch 391/5000
# Processing batch 392/5000
# Processing batch 393/5000
# Processing batch 394/5000
# Processing batch 395/5000
# Processing batch 396/5000
# Processing batch 397/5000
# Processing batch 398/5000
# Processing batch 399/5000
# Processing batch 400/5000
# Processing batch 401/5000
# Processing batch 402/5000
# Processing batch 403/5000
# Processing batch 404/5000
# Processing batch 405/5000
# Processing batch 406/5000
# Processing batch 407/5000
# Processing batch 408/5000
# Processing batch 409/5000
# Processing batch 410/5000
# Processing batch 411/5000
# Processing batch 412/5000
# Processing batch 413/5000
# Processing batch 414/5000
# Processing batch 415/5000
# Processing batch 416/5000
# Processing batch 417/5000
# Processing batch 418/5000
# Processing batch 419/5000
# Processing batch 420/5000
# Processing batch 421/5000
# Processing batch 422/5000
# Processing batch 423/5000
# Processing batch 424/5000
# Processing batch 425/5000
# Processing batch 426/5000
# Processing batch 427/5000
# Processing batch 428/5000
# Processing batch 429/5000
# Processing batch 430/5000
# Processing batch 431/5000
# Processing batch 432/5000
# Processing batch 433/5000
# Processing batch 434/5000
# Processing batch 435/5000
# Processing batch 436/5000
# Processing batch 437/5000
# Processing batch 438/5000
# Processing batch 439/5000
# Processing batch 440/5000
# Processing batch 441/5000
# Processing batch 442/5000
# Processing batch 443/5000
# Processing batch 444/5000
# Processing batch 445/5000
# Processing batch 446/5000
# Processing batch 447/5000
# Processing batch 448/5000
# Processing batch 449/5000
# Processing batch 450/5000
# Processing batch 451/5000
# Processing batch 452/5000
# Processing batch 453/5000
# Processing batch 454/5000
# Processing batch 455/5000
# Processing batch 456/5000
# Processing batch 457/5000
# Processing batch 458/5000
# Processing batch 459/5000
# Processing batch 460/5000
# Processing batch 461/5000
# Processing batch 462/5000
# Processing batch 463/5000
# Processing batch 464/5000
# Processing batch 465/5000
# Processing batch 466/5000
# Processing batch 467/5000
# Processing batch 468/5000
# Processing batch 469/5000
# Processing batch 470/5000
# Processing batch 471/5000
# Processing batch 472/5000
# Processing batch 473/5000
# Processing batch 474/5000
# Processing batch 475/5000
# Processing batch 476/5000
# Processing batch 477/5000
# Processing batch 478/5000
# Processing batch 479/5000
# Processing batch 480/5000
# Processing batch 481/5000
# Processing batch 482/5000
# Processing batch 483/5000
# Processing batch 484/5000
# Processing batch 485/5000
# Processing batch 486/5000
# Processing batch 487/5000
# Processing batch 488/5000
# Processing batch 489/5000
# Processing batch 490/5000
# Processing batch 491/5000
# Processing batch 492/5000
# Processing batch 493/5000
# Processing batch 494/5000
# Processing batch 495/5000
# Processing batch 496/5000
# Processing batch 497/5000
# Processing batch 498/5000
# Processing batch 499/5000
# Processing batch 500/5000
# Processing batch 501/5000
# Processing batch 502/5000
# Processing batch 503/5000
# Processing batch 504/5000
# Processing batch 505/5000
# Processing batch 506/5000
# Processing batch 507/5000
# Processing batch 508/5000
# Processing batch 509/5000
# Processing batch 510/5000
# Processing batch 511/5000
# Processing batch 512/5000
# Processing batch 513/5000
# Processing batch 514/5000
# Processing batch 515/5000
# Processing batch 516/5000
# Processing batch 517/5000
# Processing batch 518/5000
# Processing batch 519/5000
# Processing batch 520/5000
# Processing batch 521/5000
# Processing batch 522/5000
# Processing batch 523/5000
# Processing batch 524/5000
# Processing batch 525/5000
# Processing batch 526/5000
# Processing batch 527/5000
# Processing batch 528/5000
# Processing batch 529/5000
# Processing batch 530/5000
# Processing batch 531/5000
# Processing batch 532/5000
# Processing batch 533/5000
# Processing batch 534/5000
# Processing batch 535/5000
# Processing batch 536/5000
# Processing batch 537/5000
# Processing batch 538/5000
# Processing batch 539/5000
# Processing batch 540/5000
# Processing batch 541/5000
# Processing batch 542/5000
# Processing batch 543/5000
# Processing batch 544/5000
# Processing batch 545/5000
# Processing batch 546/5000
# Processing batch 547/5000
# Processing batch 548/5000
# Processing batch 549/5000
# Processing batch 550/5000
# Processing batch 551/5000
# Processing batch 552/5000
# Processing batch 553/5000
# Processing batch 554/5000
# Processing batch 555/5000
# Processing batch 556/5000
# Processing batch 557/5000
# Processing batch 558/5000
# Processing batch 559/5000
# Processing batch 560/5000
# Processing batch 561/5000
# Processing batch 562/5000
# Processing batch 563/5000
# Processing batch 564/5000
# Processing batch 565/5000
# Processing batch 566/5000
# Processing batch 567/5000
# Processing batch 568/5000
# Processing batch 569/5000
# Processing batch 570/5000
# Processing batch 571/5000
# Processing batch 572/5000
# Processing batch 573/5000
# Processing batch 574/5000
# Processing batch 575/5000
# Processing batch 576/5000
# Processing batch 577/5000
# Processing batch 578/5000
# Processing batch 579/5000
# Processing batch 580/5000
# Processing batch 581/5000
# Processing batch 582/5000
# Processing batch 583/5000
# Processing batch 584/5000
# Processing batch 585/5000
# Processing batch 586/5000
# Processing batch 587/5000
# Processing batch 588/5000
# Processing batch 589/5000
# Processing batch 590/5000
# Processing batch 591/5000
# Processing batch 592/5000
# Processing batch 593/5000
# Processing batch 594/5000
# Processing batch 595/5000
# Processing batch 596/5000
# Processing batch 597/5000
# Processing batch 598/5000
# Processing batch 599/5000
# Processing batch 600/5000
# Processing batch 601/5000
# Processing batch 602/5000
# Processing batch 603/5000
# Processing batch 604/5000
# Processing batch 605/5000
# Processing batch 606/5000
# Processing batch 607/5000
# Processing batch 608/5000
# Processing batch 609/5000
# Processing batch 610/5000
# Processing batch 611/5000
# Processing batch 612/5000
# Processing batch 613/5000
# Processing batch 614/5000
# Processing batch 615/5000
# Processing batch 616/5000
# Processing batch 617/5000
# Processing batch 618/5000
# Processing batch 619/5000
# Processing batch 620/5000
# Processing batch 621/5000
# Processing batch 622/5000
# Processing batch 623/5000
# Processing batch 624/5000
# Processing batch 625/5000
# Processing batch 626/5000
# Processing batch 627/5000
# Processing batch 628/5000
# Processing batch 629/5000
# Processing batch 630/5000
# Processing batch 631/5000
# Processing batch 632/5000
# Processing batch 633/5000
# Processing batch 634/5000
# Processing batch 635/5000
# Processing batch 636/5000
# Processing batch 637/5000
# Processing batch 638/5000
# Processing batch 639/5000
# Processing batch 640/5000
# Processing batch 641/5000
# Processing batch 642/5000
# Processing batch 643/5000
# Processing batch 644/5000
# Processing batch 645/5000
# Processing batch 646/5000
# Processing batch 647/5000
# Processing batch 648/5000
# Processing batch 649/5000
# Processing batch 650/5000
# Processing batch 651/5000
# Processing batch 652/5000
# Processing batch 653/5000
# Processing batch 654/5000
# Processing batch 655/5000
# Processing batch 656/5000
# Processing batch 657/5000
# Processing batch 658/5000
# Processing batch 659/5000
# Processing batch 660/5000
# Processing batch 661/5000
# Processing batch 662/5000
# Processing batch 663/5000
# Processing batch 664/5000
# Processing batch 665/5000
# Processing batch 666/5000
# Processing batch 667/5000
# Processing batch 668/5000
# Processing batch 669/5000
# Processing batch 670/5000
# Processing batch 671/5000
# Processing batch 672/5000
# Processing batch 673/5000
# Processing batch 674/5000
# Processing batch 675/5000
# Processing batch 676/5000
# Processing batch 677/5000
# Processing batch 678/5000
# Processing batch 679/5000
# Processing batch 680/5000
# Processing batch 681/5000
# Processing batch 682/5000
# Processing batch 683/5000
# Processing batch 684/5000
# Processing batch 685/5000
# Processing batch 686/5000
# Processing batch 687/5000
# Processing batch 688/5000
# Processing batch 689/5000
# Processing batch 690/5000
# Processing batch 691/5000
# Processing batch 692/5000
# Processing batch 693/5000
# Processing batch 694/5000
# Processing batch 695/5000
# Processing batch 696/5000
# Processing batch 697/5000
# Processing batch 698/5000
# Processing batch 699/5000
# Processing batch 700/5000
# Processing batch 701/5000
# Processing batch 702/5000
# Processing batch 703/5000
# Processing batch 704/5000
# Processing batch 705/5000
# Processing batch 706/5000
# Processing batch 707/5000
# Processing batch 708/5000
# Processing batch 709/5000
# Processing batch 710/5000
# Processing batch 711/5000
# Processing batch 712/5000
# Processing batch 713/5000
# Processing batch 714/5000
# Processing batch 715/5000
# Processing batch 716/5000
# Processing batch 717/5000
# Processing batch 718/5000
# Processing batch 719/5000
# Processing batch 720/5000
# Processing batch 721/5000
# Processing batch 722/5000
# Processing batch 723/5000
# Processing batch 724/5000
# Processing batch 725/5000
# Processing batch 726/5000
# Processing batch 727/5000
# Processing batch 728/5000
# Processing batch 729/5000
# Processing batch 730/5000
# Processing batch 731/5000
# Processing batch 732/5000
# Processing batch 733/5000
# Processing batch 734/5000
# Processing batch 735/5000
# Processing batch 736/5000
# Processing batch 737/5000
# Processing batch 738/5000
# Processing batch 739/5000
# Processing batch 740/5000
# Processing batch 741/5000
# Processing batch 742/5000
# Processing batch 743/5000
# Processing batch 744/5000
# Processing batch 745/5000
# Processing batch 746/5000
# Processing batch 747/5000
# Processing batch 748/5000
# Processing batch 749/5000
# Processing batch 750/5000
# Processing batch 751/5000
# Processing batch 752/5000
# Processing batch 753/5000
# Processing batch 754/5000
# Processing batch 755/5000
# Processing batch 756/5000
# Processing batch 757/5000
# Processing batch 758/5000
# Processing batch 759/5000
# Processing batch 760/5000
# Processing batch 761/5000
# Processing batch 762/5000
# Processing batch 763/5000
# Processing batch 764/5000
# Processing batch 765/5000
# Processing batch 766/5000
# Processing batch 767/5000
# Processing batch 768/5000
# Processing batch 769/5000
# Processing batch 770/5000
# Processing batch 771/5000
# Processing batch 772/5000
# Processing batch 773/5000
# Processing batch 774/5000
# Processing batch 775/5000
# Processing batch 776/5000
# Processing batch 777/5000
# Processing batch 778/5000
# Processing batch 779/5000
# Processing batch 780/5000
# Processing batch 781/5000
# Processing batch 782/5000
# Processing batch 783/5000
# Processing batch 784/5000
# Processing batch 785/5000
# Processing batch 786/5000
# Processing batch 787/5000
# Processing batch 788/5000
# Processing batch 789/5000
# Processing batch 790/5000
# Processing batch 791/5000
# Processing batch 792/5000
# Processing batch 793/5000
# Processing batch 794/5000
# Processing batch 795/5000
# Processing batch 796/5000
# Processing batch 797/5000
# Processing batch 798/5000
# Processing batch 799/5000
# Processing batch 800/5000
# Processing batch 801/5000
# Processing batch 802/5000
# Processing batch 803/5000
# Processing batch 804/5000
# Processing batch 805/5000
# Processing batch 806/5000
# Processing batch 807/5000
# Processing batch 808/5000
# Processing batch 809/5000
# Processing batch 810/5000
# Processing batch 811/5000
# Processing batch 812/5000
# Processing batch 813/5000
# Processing batch 814/5000
# Processing batch 815/5000
# Processing batch 816/5000
# Processing batch 817/5000
# Processing batch 818/5000
# Processing batch 819/5000
# Processing batch 820/5000
# Processing batch 821/5000
# Processing batch 822/5000
# Processing batch 823/5000
# Processing batch 824/5000
# Processing batch 825/5000
# Processing batch 826/5000
# Processing batch 827/5000
# Processing batch 828/5000
# Processing batch 829/5000
# Processing batch 830/5000
# Processing batch 831/5000
# Processing batch 832/5000
# Processing batch 833/5000
# Processing batch 834/5000
# Processing batch 835/5000
# Processing batch 836/5000
# Processing batch 837/5000
# Processing batch 838/5000
# Processing batch 839/5000
# Processing batch 840/5000
# Processing batch 841/5000
# Processing batch 842/5000
# Processing batch 843/5000
# Processing batch 844/5000
# Processing batch 845/5000
# Processing batch 846/5000
# Processing batch 847/5000
# Processing batch 848/5000
# Processing batch 849/5000
# Processing batch 850/5000
# Processing batch 851/5000
# Processing batch 852/5000
# Processing batch 853/5000
# Processing batch 854/5000
# Processing batch 855/5000
# Processing batch 856/5000
# Processing batch 857/5000
# Processing batch 858/5000
# Processing batch 859/5000
# Processing batch 860/5000
# Processing batch 861/5000
# Processing batch 862/5000
# Processing batch 863/5000
# Processing batch 864/5000
# Processing batch 865/5000
# Processing batch 866/5000
# Processing batch 867/5000
# Processing batch 868/5000
# Processing batch 869/5000
# Processing batch 870/5000
# Processing batch 871/5000
# Processing batch 872/5000
# Processing batch 873/5000
# Processing batch 874/5000
# Processing batch 875/5000
# Processing batch 876/5000
# Processing batch 877/5000
# Processing batch 878/5000
# Processing batch 879/5000
# Processing batch 880/5000
# Processing batch 881/5000
# Processing batch 882/5000
# Processing batch 883/5000
# Processing batch 884/5000
# Processing batch 885/5000
# Processing batch 886/5000
# Processing batch 887/5000
# Processing batch 888/5000
# Processing batch 889/5000
# Processing batch 890/5000
# Processing batch 891/5000
# Processing batch 892/5000
# Processing batch 893/5000
# Processing batch 894/5000
# Processing batch 895/5000
# Processing batch 896/5000
# Processing batch 897/5000
# Processing batch 898/5000
# Processing batch 899/5000
# Processing batch 900/5000
# Processing batch 901/5000
# Processing batch 902/5000
# Processing batch 903/5000
# Processing batch 904/5000
# Processing batch 905/5000
# Processing batch 906/5000
# Processing batch 907/5000
# Processing batch 908/5000
# Processing batch 909/5000
# Processing batch 910/5000
# Processing batch 911/5000
# Processing batch 912/5000
# Processing batch 913/5000
# Processing batch 914/5000
# Processing batch 915/5000
# Processing batch 916/5000
# Processing batch 917/5000
# Processing batch 918/5000
# Processing batch 919/5000
# Processing batch 920/5000
# Processing batch 921/5000
# Processing batch 922/5000
# Processing batch 923/5000
# Processing batch 924/5000
# Processing batch 925/5000
# Processing batch 926/5000
# Processing batch 927/5000
# Processing batch 928/5000
# Processing batch 929/5000
# Processing batch 930/5000
# Processing batch 931/5000
# Processing batch 932/5000
# Processing batch 933/5000
# Processing batch 934/5000
# Processing batch 935/5000
# Processing batch 936/5000
# Processing batch 937/5000
# Processing batch 938/5000
# Processing batch 939/5000
# Processing batch 940/5000
# Processing batch 941/5000
# Processing batch 942/5000
# Processing batch 943/5000
# Processing batch 944/5000
# Processing batch 945/5000
# Processing batch 946/5000
# Processing batch 947/5000
# Processing batch 948/5000
# Processing batch 949/5000
# Processing batch 950/5000
# Processing batch 951/5000
# Processing batch 952/5000
# Processing batch 953/5000
# Processing batch 954/5000
# Processing batch 955/5000
# Processing batch 956/5000
# Processing batch 957/5000
# Processing batch 958/5000
# Processing batch 959/5000
# Processing batch 960/5000
# Processing batch 961/5000
# Processing batch 962/5000
# Processing batch 963/5000
# Processing batch 964/5000
# Processing batch 965/5000
# Processing batch 966/5000
# Processing batch 967/5000
# Processing batch 968/5000
# Processing batch 969/5000
# Processing batch 970/5000
# Processing batch 971/5000
# Processing batch 972/5000
# Processing batch 973/5000
# Processing batch 974/5000
# Processing batch 975/5000
# Processing batch 976/5000
# Processing batch 977/5000
# Processing batch 978/5000
# Processing batch 979/5000
# Processing batch 980/5000
# Processing batch 981/5000
# Processing batch 982/5000
# Processing batch 983/5000
# Processing batch 984/5000
# Processing batch 985/5000
# Processing batch 986/5000
# Processing batch 987/5000
# Processing batch 988/5000
# Processing batch 989/5000
# Processing batch 990/5000
# Processing batch 991/5000
# Processing batch 992/5000
# Processing batch 993/5000
# Processing batch 994/5000
# Processing batch 995/5000
# Processing batch 996/5000
# Processing batch 997/5000
# Processing batch 998/5000
# Processing batch 999/5000
# Processing batch 1000/5000
# Processing batch 1001/5000
# Processing batch 1002/5000
# Processing batch 1003/5000
# Processing batch 1004/5000
# Processing batch 1005/5000
# Processing batch 1006/5000
# Processing batch 1007/5000
# Processing batch 1008/5000
# Processing batch 1009/5000
# Processing batch 1010/5000
# Processing batch 1011/5000
# Processing batch 1012/5000
# Processing batch 1013/5000
# Processing batch 1014/5000
# Processing batch 1015/5000
# Processing batch 1016/5000
# Processing batch 1017/5000
# Processing batch 1018/5000
# Processing batch 1019/5000
# Processing batch 1020/5000
# Processing batch 1021/5000
# Processing batch 1022/5000
# Processing batch 1023/5000
# Processing batch 1024/5000
# Processing batch 1025/5000
# Processing batch 1026/5000
# Processing batch 1027/5000
# Processing batch 1028/5000
# Processing batch 1029/5000
# Processing batch 1030/5000
# Processing batch 1031/5000
# Processing batch 1032/5000
# Processing batch 1033/5000
# Processing batch 1034/5000
# Processing batch 1035/5000
# Processing batch 1036/5000
# Processing batch 1037/5000
# Processing batch 1038/5000
# Processing batch 1039/5000
# Processing batch 1040/5000
# Processing batch 1041/5000
# Processing batch 1042/5000
# Processing batch 1043/5000
# Processing batch 1044/5000
# Processing batch 1045/5000
# Processing batch 1046/5000
# Processing batch 1047/5000
# Processing batch 1048/5000
# Processing batch 1049/5000
# Processing batch 1050/5000
# Processing batch 1051/5000
# Processing batch 1052/5000
# Processing batch 1053/5000
# Processing batch 1054/5000
# Processing batch 1055/5000
# Processing batch 1056/5000
# Processing batch 1057/5000
# Processing batch 1058/5000
# Processing batch 1059/5000
# Processing batch 1060/5000
# Processing batch 1061/5000
# Processing batch 1062/5000
# Processing batch 1063/5000
# Processing batch 1064/5000
# Processing batch 1065/5000
# Processing batch 1066/5000
# Processing batch 1067/5000
# Processing batch 1068/5000
# Processing batch 1069/5000
# Processing batch 1070/5000
# Processing batch 1071/5000
# Processing batch 1072/5000
# Processing batch 1073/5000
# Processing batch 1074/5000
# Processing batch 1075/5000
# Processing batch 1076/5000
# Processing batch 1077/5000
# Processing batch 1078/5000
# Processing batch 1079/5000
# Processing batch 1080/5000
# Processing batch 1081/5000
# Processing batch 1082/5000
# Processing batch 1083/5000
# Processing batch 1084/5000
# Processing batch 1085/5000
# Processing batch 1086/5000
# Processing batch 1087/5000
# Processing batch 1088/5000
# Processing batch 1089/5000
# Processing batch 1090/5000
# Processing batch 1091/5000
# Processing batch 1092/5000
# Processing batch 1093/5000
# Processing batch 1094/5000
# Processing batch 1095/5000
# Processing batch 1096/5000
# Processing batch 1097/5000
# Processing batch 1098/5000
# Processing batch 1099/5000
# Processing batch 1100/5000
# Processing batch 1101/5000
# Processing batch 1102/5000
# Processing batch 1103/5000
# Processing batch 1104/5000
# Processing batch 1105/5000
# Processing batch 1106/5000
# Processing batch 1107/5000
# Processing batch 1108/5000
# Processing batch 1109/5000
# Processing batch 1110/5000
# Processing batch 1111/5000
# Processing batch 1112/5000
# Processing batch 1113/5000
# Processing batch 1114/5000
# Processing batch 1115/5000
# Processing batch 1116/5000
# Processing batch 1117/5000
# Processing batch 1118/5000
# Processing batch 1119/5000
# Processing batch 1120/5000
# Processing batch 1121/5000
# Processing batch 1122/5000
# Processing batch 1123/5000
# Processing batch 1124/5000
# Processing batch 1125/5000
# Processing batch 1126/5000
# Processing batch 1127/5000
# Processing batch 1128/5000
# Processing batch 1129/5000
# Processing batch 1130/5000
# Processing batch 1131/5000
# Processing batch 1132/5000
# Processing batch 1133/5000
# Processing batch 1134/5000
# Processing batch 1135/5000
# Processing batch 1136/5000
# Processing batch 1137/5000
# Processing batch 1138/5000
# Processing batch 1139/5000
# Processing batch 1140/5000
# Processing batch 1141/5000
# Processing batch 1142/5000
# Processing batch 1143/5000
# Processing batch 1144/5000
# Processing batch 1145/5000
# Processing batch 1146/5000
# Processing batch 1147/5000
# Processing batch 1148/5000
# Processing batch 1149/5000
# Processing batch 1150/5000
# Processing batch 1151/5000
# Processing batch 1152/5000
# Processing batch 1153/5000
# Processing batch 1154/5000
# Processing batch 1155/5000
# Processing batch 1156/5000
# Processing batch 1157/5000
# Processing batch 1158/5000
# Processing batch 1159/5000
# Processing batch 1160/5000
# Processing batch 1161/5000
# Processing batch 1162/5000
# Processing batch 1163/5000
# Processing batch 1164/5000
# Processing batch 1165/5000
# Processing batch 1166/5000
# Processing batch 1167/5000
# Processing batch 1168/5000
# Processing batch 1169/5000
# Processing batch 1170/5000
# Processing batch 1171/5000
# Processing batch 1172/5000
# Processing batch 1173/5000
# Processing batch 1174/5000
# Processing batch 1175/5000
# Processing batch 1176/5000
# Processing batch 1177/5000
# Processing batch 1178/5000
# Processing batch 1179/5000
# Processing batch 1180/5000
# Processing batch 1181/5000
# Processing batch 1182/5000
# Processing batch 1183/5000
# Processing batch 1184/5000
# Processing batch 1185/5000
# Processing batch 1186/5000
# Processing batch 1187/5000
# Processing batch 1188/5000
# Processing batch 1189/5000
# Processing batch 1190/5000
# Processing batch 1191/5000
# Processing batch 1192/5000
# Processing batch 1193/5000
# Processing batch 1194/5000
# Processing batch 1195/5000
# Processing batch 1196/5000
# Processing batch 1197/5000
# Processing batch 1198/5000
# Processing batch 1199/5000
# Processing batch 1200/5000
# Processing batch 1201/5000
# Processing batch 1202/5000
# Processing batch 1203/5000
# Processing batch 1204/5000
# Processing batch 1205/5000
# Processing batch 1206/5000
# Processing batch 1207/5000
# Processing batch 1208/5000
# Processing batch 1209/5000
# Processing batch 1210/5000
# Processing batch 1211/5000
# Processing batch 1212/5000
# Processing batch 1213/5000
# Processing batch 1214/5000
# Processing batch 1215/5000
# Processing batch 1216/5000
# Processing batch 1217/5000
# Processing batch 1218/5000
# Processing batch 1219/5000
# Processing batch 1220/5000
# Processing batch 1221/5000
# Processing batch 1222/5000
# Processing batch 1223/5000
# Processing batch 1224/5000
# Processing batch 1225/5000
# Processing batch 1226/5000
# Processing batch 1227/5000
# Processing batch 1228/5000
# Processing batch 1229/5000
# Processing batch 1230/5000
# Processing batch 1231/5000
# Processing batch 1232/5000
# Processing batch 1233/5000
# Processing batch 1234/5000
# Processing batch 1235/5000
# Processing batch 1236/5000
# Processing batch 1237/5000
# Processing batch 1238/5000
# Processing batch 1239/5000
# Processing batch 1240/5000
# Processing batch 1241/5000
# Processing batch 1242/5000
# Processing batch 1243/5000
# Processing batch 1244/5000
# Processing batch 1245/5000
# Processing batch 1246/5000
# Processing batch 1247/5000
# Processing batch 1248/5000
# Processing batch 1249/5000
# Processing batch 1250/5000
# Processing batch 1251/5000
# Processing batch 1252/5000
# Processing batch 1253/5000
# Processing batch 1254/5000
# Processing batch 1255/5000
# Processing batch 1256/5000
# Processing batch 1257/5000
# Processing batch 1258/5000
# Processing batch 1259/5000
# Processing batch 1260/5000
# Processing batch 1261/5000
# Processing batch 1262/5000
# Processing batch 1263/5000
# Processing batch 1264/5000
# Processing batch 1265/5000
# Processing batch 1266/5000
# Processing batch 1267/5000
# Processing batch 1268/5000
# Processing batch 1269/5000
# Processing batch 1270/5000
# Processing batch 1271/5000
# Processing batch 1272/5000
# Processing batch 1273/5000
# Processing batch 1274/5000
# Processing batch 1275/5000
# Processing batch 1276/5000
# Processing batch 1277/5000
# Processing batch 1278/5000
# Processing batch 1279/5000
# Processing batch 1280/5000
# Processing batch 1281/5000
# Processing batch 1282/5000
# Processing batch 1283/5000
# Processing batch 1284/5000
# Processing batch 1285/5000
# Processing batch 1286/5000
# Processing batch 1287/5000
# Processing batch 1288/5000
# Processing batch 1289/5000
# Processing batch 1290/5000
# Processing batch 1291/5000
# Processing batch 1292/5000
# Processing batch 1293/5000
# Processing batch 1294/5000
# Processing batch 1295/5000
# Processing batch 1296/5000
# Processing batch 1297/5000
# Processing batch 1298/5000
# Processing batch 1299/5000
# Processing batch 1300/5000
# Processing batch 1301/5000
# Processing batch 1302/5000
# Processing batch 1303/5000
# Processing batch 1304/5000
# Processing batch 1305/5000
# Processing batch 1306/5000
# Processing batch 1307/5000
# Processing batch 1308/5000
# Processing batch 1309/5000
# Processing batch 1310/5000
# Processing batch 1311/5000
# Processing batch 1312/5000
# Processing batch 1313/5000
# Processing batch 1314/5000
# Processing batch 1315/5000
# Processing batch 1316/5000
# Processing batch 1317/5000
# Processing batch 1318/5000
# Processing batch 1319/5000
# Processing batch 1320/5000
# Processing batch 1321/5000
# Processing batch 1322/5000
# Processing batch 1323/5000
# Processing batch 1324/5000
# Processing batch 1325/5000
# Processing batch 1326/5000
# Processing batch 1327/5000
# Processing batch 1328/5000
# Processing batch 1329/5000
# Processing batch 1330/5000
# Processing batch 1331/5000
# Processing batch 1332/5000
# Processing batch 1333/5000
# Processing batch 1334/5000
# Processing batch 1335/5000
# Processing batch 1336/5000
# Processing batch 1337/5000
# Processing batch 1338/5000
# Processing batch 1339/5000
# Processing batch 1340/5000
# Processing batch 1341/5000
# Processing batch 1342/5000
# Processing batch 1343/5000
# Processing batch 1344/5000
# Processing batch 1345/5000
# Processing batch 1346/5000
# Processing batch 1347/5000
# Processing batch 1348/5000
# Processing batch 1349/5000
# Processing batch 1350/5000
# Processing batch 1351/5000
# Processing batch 1352/5000
# Processing batch 1353/5000
# Processing batch 1354/5000
# Processing batch 1355/5000
# Processing batch 1356/5000
# Processing batch 1357/5000
# Processing batch 1358/5000
# Processing batch 1359/5000
# Processing batch 1360/5000
# Processing batch 1361/5000
# Processing batch 1362/5000
# Processing batch 1363/5000
# Processing batch 1364/5000
# Processing batch 1365/5000
# Processing batch 1366/5000
# Processing batch 1367/5000
# Processing batch 1368/5000
# Processing batch 1369/5000
# Processing batch 1370/5000
# Processing batch 1371/5000
# Processing batch 1372/5000
# Processing batch 1373/5000
# Processing batch 1374/5000
# Processing batch 1375/5000
# Processing batch 1376/5000
# Processing batch 1377/5000
# Processing batch 1378/5000
# Processing batch 1379/5000
# Processing batch 1380/5000
# Processing batch 1381/5000
# Processing batch 1382/5000
# Processing batch 1383/5000
# Processing batch 1384/5000
# Processing batch 1385/5000
# Processing batch 1386/5000
# Processing batch 1387/5000
# Processing batch 1388/5000
# Processing batch 1389/5000
# Processing batch 1390/5000
# Processing batch 1391/5000
# Processing batch 1392/5000
# Processing batch 1393/5000
# Processing batch 1394/5000
# Processing batch 1395/5000
# Processing batch 1396/5000
# Processing batch 1397/5000
# Processing batch 1398/5000
# Processing batch 1399/5000
# Processing batch 1400/5000
# Processing batch 1401/5000
# Processing batch 1402/5000
# Processing batch 1403/5000
# Processing batch 1404/5000
# Processing batch 1405/5000
# Processing batch 1406/5000
# Processing batch 1407/5000
# Processing batch 1408/5000
# Processing batch 1409/5000
# Processing batch 1410/5000
# Processing batch 1411/5000
# Processing batch 1412/5000
# Processing batch 1413/5000
# Processing batch 1414/5000
# Processing batch 1415/5000
# Processing batch 1416/5000
# Processing batch 1417/5000
# Processing batch 1418/5000
# Processing batch 1419/5000
# Processing batch 1420/5000
# Processing batch 1421/5000
# Processing batch 1422/5000
# Processing batch 1423/5000
# Processing batch 1424/5000
# Processing batch 1425/5000
# Processing batch 1426/5000
# Processing batch 1427/5000
# Processing batch 1428/5000
# Processing batch 1429/5000
# Processing batch 1430/5000
# Processing batch 1431/5000
# Processing batch 1432/5000
# Processing batch 1433/5000
# Processing batch 1434/5000
# Processing batch 1435/5000
# Processing batch 1436/5000
# Processing batch 1437/5000
# Processing batch 1438/5000
# Processing batch 1439/5000
# Processing batch 1440/5000
# Processing batch 1441/5000
# Processing batch 1442/5000
# Processing batch 1443/5000
# Processing batch 1444/5000
# Processing batch 1445/5000
# Processing batch 1446/5000
# Processing batch 1447/5000
# Processing batch 1448/5000
# Processing batch 1449/5000
# Processing batch 1450/5000
# Processing batch 1451/5000
# Processing batch 1452/5000
# Processing batch 1453/5000
# Processing batch 1454/5000
# Processing batch 1455/5000
# Processing batch 1456/5000
# Processing batch 1457/5000
# Processing batch 1458/5000
# Processing batch 1459/5000
# Processing batch 1460/5000
# Processing batch 1461/5000
# Processing batch 1462/5000
# Processing batch 1463/5000
# Processing batch 1464/5000
# Processing batch 1465/5000
# Processing batch 1466/5000
# Processing batch 1467/5000
# Processing batch 1468/5000
# Processing batch 1469/5000
# Processing batch 1470/5000
# Processing batch 1471/5000
# Processing batch 1472/5000
# Processing batch 1473/5000
# Processing batch 1474/5000
# Processing batch 1475/5000
# Processing batch 1476/5000
# Processing batch 1477/5000
# Processing batch 1478/5000
# Processing batch 1479/5000
# Processing batch 1480/5000
# Processing batch 1481/5000
# Processing batch 1482/5000
# Processing batch 1483/5000
# Processing batch 1484/5000
# Processing batch 1485/5000
# Processing batch 1486/5000
# Processing batch 1487/5000
# Processing batch 1488/5000
# Processing batch 1489/5000
# Processing batch 1490/5000
# Processing batch 1491/5000
# Processing batch 1492/5000
# Processing batch 1493/5000
# Processing batch 1494/5000
# Processing batch 1495/5000
# Processing batch 1496/5000
# Processing batch 1497/5000
# Processing batch 1498/5000
# Processing batch 1499/5000
# Processing batch 1500/5000
# Processing batch 1501/5000
# Processing batch 1502/5000
# Processing batch 1503/5000
# Processing batch 1504/5000
# Processing batch 1505/5000
# Processing batch 1506/5000
# Processing batch 1507/5000
# Processing batch 1508/5000
# Processing batch 1509/5000
# Processing batch 1510/5000
# Processing batch 1511/5000
# Processing batch 1512/5000
# Processing batch 1513/5000
# Processing batch 1514/5000
# Processing batch 1515/5000
# Processing batch 1516/5000
# Processing batch 1517/5000
# Processing batch 1518/5000
# Processing batch 1519/5000
# Processing batch 1520/5000
# Processing batch 1521/5000
# Processing batch 1522/5000
# Processing batch 1523/5000
# Processing batch 1524/5000
# Processing batch 1525/5000
# Processing batch 1526/5000
# Processing batch 1527/5000
# Processing batch 1528/5000
# Processing batch 1529/5000
# Processing batch 1530/5000
# Processing batch 1531/5000
# Processing batch 1532/5000
# Processing batch 1533/5000
# Processing batch 1534/5000
# Processing batch 1535/5000
# Processing batch 1536/5000
# Processing batch 1537/5000
# Processing batch 1538/5000
# Processing batch 1539/5000
# Processing batch 1540/5000
# Processing batch 1541/5000
# Processing batch 1542/5000
# Processing batch 1543/5000
# Processing batch 1544/5000
# Processing batch 1545/5000
# Processing batch 1546/5000
# Processing batch 1547/5000
# Processing batch 1548/5000
# Processing batch 1549/5000
# Processing batch 1550/5000
# Processing batch 1551/5000
# Processing batch 1552/5000
# Processing batch 1553/5000
# Processing batch 1554/5000
# Processing batch 1555/5000
# Processing batch 1556/5000
# Processing batch 1557/5000
# Processing batch 1558/5000
# Processing batch 1559/5000
# Processing batch 1560/5000
# Processing batch 1561/5000
# Processing batch 1562/5000
# Processing batch 1563/5000
# Processing batch 1564/5000
# Processing batch 1565/5000
# Processing batch 1566/5000
# Processing batch 1567/5000
# Processing batch 1568/5000
# Processing batch 1569/5000
# Processing batch 1570/5000
# Processing batch 1571/5000
# Processing batch 1572/5000
# Processing batch 1573/5000
# Processing batch 1574/5000
# Processing batch 1575/5000
# Processing batch 1576/5000
# Processing batch 1577/5000
# Processing batch 1578/5000
# Processing batch 1579/5000
# Processing batch 1580/5000
# Processing batch 1581/5000
# Processing batch 1582/5000
# Processing batch 1583/5000
# Processing batch 1584/5000
# Processing batch 1585/5000
# Processing batch 1586/5000
# Processing batch 1587/5000
# Processing batch 1588/5000
# Processing batch 1589/5000
# Processing batch 1590/5000
# Processing batch 1591/5000
# Processing batch 1592/5000
# Processing batch 1593/5000
# Processing batch 1594/5000
# Processing batch 1595/5000
# Processing batch 1596/5000
# Processing batch 1597/5000
# Processing batch 1598/5000
# Processing batch 1599/5000
# Processing batch 1600/5000
# Processing batch 1601/5000
# Processing batch 1602/5000
# Processing batch 1603/5000
# Processing batch 1604/5000
# Processing batch 1605/5000
# Processing batch 1606/5000
# Processing batch 1607/5000
# Processing batch 1608/5000
# Processing batch 1609/5000
# Processing batch 1610/5000
# Processing batch 1611/5000
# Processing batch 1612/5000
# Processing batch 1613/5000
# Processing batch 1614/5000
# Processing batch 1615/5000
# Processing batch 1616/5000
# Processing batch 1617/5000
# Processing batch 1618/5000
# Processing batch 1619/5000
# Processing batch 1620/5000
# Processing batch 1621/5000
# Processing batch 1622/5000
# Processing batch 1623/5000
# Processing batch 1624/5000
# Processing batch 1625/5000
# Processing batch 1626/5000
# Processing batch 1627/5000
# Processing batch 1628/5000
# Processing batch 1629/5000
# Processing batch 1630/5000
# Processing batch 1631/5000
# Processing batch 1632/5000
# Processing batch 1633/5000
# Processing batch 1634/5000
# Processing batch 1635/5000
# Processing batch 1636/5000
# Processing batch 1637/5000
# Processing batch 1638/5000
# Processing batch 1639/5000
# Processing batch 1640/5000
# Processing batch 1641/5000
# Processing batch 1642/5000
# Processing batch 1643/5000
# Processing batch 1644/5000
# Processing batch 1645/5000
# Processing batch 1646/5000
# Processing batch 1647/5000
# Processing batch 1648/5000
# Processing batch 1649/5000
# Processing batch 1650/5000
# Processing batch 1651/5000
# Processing batch 1652/5000
# Processing batch 1653/5000
# Processing batch 1654/5000
# Processing batch 1655/5000
# Processing batch 1656/5000
# Processing batch 1657/5000
# Processing batch 1658/5000
# Processing batch 1659/5000
# Processing batch 1660/5000
# Processing batch 1661/5000
# Processing batch 1662/5000
# Processing batch 1663/5000
# Processing batch 1664/5000
# Processing batch 1665/5000
# Processing batch 1666/5000
# Processing batch 1667/5000
# Processing batch 1668/5000
# Processing batch 1669/5000
# Processing batch 1670/5000
# Processing batch 1671/5000
# Processing batch 1672/5000
# Processing batch 1673/5000
# Processing batch 1674/5000
# Processing batch 1675/5000
# Processing batch 1676/5000
# Processing batch 1677/5000
# Processing batch 1678/5000
# Processing batch 1679/5000
# Processing batch 1680/5000
# Processing batch 1681/5000
# Processing batch 1682/5000
# Processing batch 1683/5000
# Processing batch 1684/5000
# Processing batch 1685/5000
# Processing batch 1686/5000
# Processing batch 1687/5000
# Processing batch 1688/5000
# Processing batch 1689/5000
# Processing batch 1690/5000
# Processing batch 1691/5000
# Processing batch 1692/5000
# Processing batch 1693/5000
# Processing batch 1694/5000
# Processing batch 1695/5000
# Processing batch 1696/5000
# Processing batch 1697/5000
# Processing batch 1698/5000
# Processing batch 1699/5000
# Processing batch 1700/5000
# Processing batch 1701/5000
# Processing batch 1702/5000
# Processing batch 1703/5000
# Processing batch 1704/5000
# Processing batch 1705/5000
# Processing batch 1706/5000
# Processing batch 1707/5000
# Processing batch 1708/5000
# Processing batch 1709/5000
# Processing batch 1710/5000
# Processing batch 1711/5000
# Processing batch 1712/5000
# Processing batch 1713/5000
# Processing batch 1714/5000
# Processing batch 1715/5000
# Processing batch 1716/5000
# Processing batch 1717/5000
# Processing batch 1718/5000
# Processing batch 1719/5000
# Processing batch 1720/5000
# Processing batch 1721/5000
# Processing batch 1722/5000
# Processing batch 1723/5000
# Processing batch 1724/5000
# Processing batch 1725/5000
# Processing batch 1726/5000
# Processing batch 1727/5000
# Processing batch 1728/5000
# Processing batch 1729/5000
# Processing batch 1730/5000
# Processing batch 1731/5000
# Processing batch 1732/5000
# Processing batch 1733/5000
# Processing batch 1734/5000
# Processing batch 1735/5000
# Processing batch 1736/5000
# Processing batch 1737/5000
# Processing batch 1738/5000
# Processing batch 1739/5000
# Processing batch 1740/5000
# Processing batch 1741/5000
# Processing batch 1742/5000
# Processing batch 1743/5000
# Processing batch 1744/5000
# Processing batch 1745/5000
# Processing batch 1746/5000
# Processing batch 1747/5000
# Processing batch 1748/5000
# Processing batch 1749/5000
# Processing batch 1750/5000
# Processing batch 1751/5000
# Processing batch 1752/5000
# Processing batch 1753/5000
# Processing batch 1754/5000
# Processing batch 1755/5000
# Processing batch 1756/5000
# Processing batch 1757/5000
# Processing batch 1758/5000
# Processing batch 1759/5000
# Processing batch 1760/5000
# Processing batch 1761/5000
# Processing batch 1762/5000
# Processing batch 1763/5000
# Processing batch 1764/5000
# Processing batch 1765/5000
# Processing batch 1766/5000
# Processing batch 1767/5000
# Processing batch 1768/5000
# Processing batch 1769/5000
# Processing batch 1770/5000
# Processing batch 1771/5000
# Processing batch 1772/5000
# Processing batch 1773/5000
# Processing batch 1774/5000
# Processing batch 1775/5000
# Processing batch 1776/5000
# Processing batch 1777/5000
# Processing batch 1778/5000
# Processing batch 1779/5000
# Processing batch 1780/5000
# Processing batch 1781/5000
# Processing batch 1782/5000
# Processing batch 1783/5000
# Processing batch 1784/5000
# Processing batch 1785/5000
# Processing batch 1786/5000
# Processing batch 1787/5000
# Processing batch 1788/5000
# Processing batch 1789/5000
# Processing batch 1790/5000
# Processing batch 1791/5000
# Processing batch 1792/5000
# Processing batch 1793/5000
# Processing batch 1794/5000
# Processing batch 1795/5000
# Processing batch 1796/5000
# Processing batch 1797/5000
# Processing batch 1798/5000
# Processing batch 1799/5000
# ...
# Processing batch 4506/5000
# Processing batch 4507/5000
# Processing batch 4508/5000
# Processing batch 4509/5000
# Processing batch 4510/5000
# Processing batch 4511/5000
# Processing batch 4512/5000
# Processing batch 4513/5000
# Processing batch 4514/5000
# Processing batch 4515/5000
# Processing batch 4516/5000
# Processing batch 4517/5000
# Processing batch 4518/5000
# Processing batch 4519/5000
# Processing batch 4520/5000
# Processing batch 4521/5000
# Processing batch 4522/5000
# Processing batch 4523/5000
# Processing batch 4524/5000
# Processing batch 4525/5000
# Processing batch 4526/5000
# Processing batch 4527/5000
# Processing batch 4528/5000
# Processing batch 4529/5000
# Processing batch 4530/5000
# Processing batch 4531/5000
# Processing batch 4532/5000
# Processing batch 4533/5000
# Processing batch 4534/5000
# Processing batch 4535/5000
# Processing batch 4536/5000
# Processing batch 4537/5000
# Processing batch 4538/5000
# Processing batch 4539/5000
# Processing batch 4540/5000
# Processing batch 4541/5000
# Processing batch 4542/5000
# Processing batch 4543/5000
# Processing batch 4544/5000
# Processing batch 4545/5000
# Processing batch 4546/5000
# Processing batch 4547/5000
# Processing batch 4548/5000
# Processing batch 4549/5000
# Processing batch 4550/5000
# Processing batch 4551/5000
# Processing batch 4552/5000
# Processing batch 4553/5000
# Processing batch 4554/5000
# Processing batch 4555/5000
# Processing batch 4556/5000
# Processing batch 4557/5000
# Processing batch 4558/5000
# Processing batch 4559/5000
# Processing batch 4560/5000
# Processing batch 4561/5000
# Processing batch 4562/5000
# Processing batch 4563/5000
# Processing batch 4564/5000
# Processing batch 4565/5000
# Processing batch 4566/5000
# Processing batch 4567/5000
# Processing batch 4568/5000
# Processing batch 4569/5000
# Processing batch 4570/5000
# Processing batch 4571/5000
# Processing batch 4572/5000
# Processing batch 4573/5000
# Processing batch 4574/5000
# Processing batch 4575/5000
# Processing batch 4576/5000
# Processing batch 4577/5000
# Processing batch 4578/5000
# Processing batch 4579/5000
# Processing batch 4580/5000
# Processing batch 4581/5000
# Processing batch 4582/5000
# Processing batch 4583/5000
# Processing batch 4584/5000
# Processing batch 4585/5000
# Processing batch 4586/5000
# Processing batch 4587/5000
# Processing batch 4588/5000
# Processing batch 4589/5000
# Processing batch 4590/5000
# Processing batch 4591/5000
# Processing batch 4592/5000
# Processing batch 4593/5000
# Processing batch 4594/5000
# Processing batch 4595/5000
# Processing batch 4596/5000
# Processing batch 4597/5000
# Processing batch 4598/5000
# Processing batch 4599/5000
# Processing batch 4600/5000
# Processing batch 4601/5000
# Processing batch 4602/5000
# Processing batch 4603/5000
# Processing batch 4604/5000
# Processing batch 4605/5000
# Processing batch 4606/5000
# Processing batch 4607/5000
# Processing batch 4608/5000
# Processing batch 4609/5000
# Processing batch 4610/5000
# Processing batch 4611/5000
# Processing batch 4612/5000
# Processing batch 4613/5000
# Processing batch 4614/5000
# Processing batch 4615/5000
# Processing batch 4616/5000
# Processing batch 4617/5000
# Processing batch 4618/5000
# Processing batch 4619/5000
# Processing batch 4620/5000
# Processing batch 4621/5000
# Processing batch 4622/5000
# Processing batch 4623/5000
# Processing batch 4624/5000
# Processing batch 4625/5000
# Processing batch 4626/5000
# Processing batch 4627/5000
# Processing batch 4628/5000
# Processing batch 4629/5000
# Processing batch 4630/5000
# Processing batch 4631/5000
# Processing batch 4632/5000
# Processing batch 4633/5000
# Processing batch 4634/5000
# Processing batch 4635/5000
# Processing batch 4636/5000
# Processing batch 4637/5000
# Processing batch 4638/5000
# Processing batch 4639/5000
# Processing batch 4640/5000
# Processing batch 4641/5000
# Processing batch 4642/5000
# Processing batch 4643/5000
# Processing batch 4644/5000
# Processing batch 4645/5000
# Processing batch 4646/5000
# Processing batch 4647/5000
# Processing batch 4648/5000
# Processing batch 4649/5000
# Processing batch 4650/5000
# Processing batch 4651/5000
# Processing batch 4652/5000
# Processing batch 4653/5000
# Processing batch 4654/5000
# Processing batch 4655/5000
# Processing batch 4656/5000
# Processing batch 4657/5000
# Processing batch 4658/5000
# Processing batch 4659/5000
# Processing batch 4660/5000
# Processing batch 4661/5000
# Processing batch 4662/5000
# Processing batch 4663/5000
# Processing batch 4664/5000
# Processing batch 4665/5000
# Processing batch 4666/5000
# Processing batch 4667/5000
# Processing batch 4668/5000
# Processing batch 4669/5000
# Processing batch 4670/5000
# Processing batch 4671/5000
# Processing batch 4672/5000
# Processing batch 4673/5000
# Processing batch 4674/5000
# Processing batch 4675/5000
# Processing batch 4676/5000
# Processing batch 4677/5000
# Processing batch 4678/5000
# Processing batch 4679/5000
# Processing batch 4680/5000
# Processing batch 4681/5000
# Processing batch 4682/5000
# Processing batch 4683/5000
# Processing batch 4684/5000
# Processing batch 4685/5000
# Processing batch 4686/5000
# Processing batch 4687/5000
# Processing batch 4688/5000
# Processing batch 4689/5000
# Processing batch 4690/5000
# Processing batch 4691/5000
# Processing batch 4692/5000
# Processing batch 4693/5000
# Processing batch 4694/5000
# Processing batch 4695/5000
# Processing batch 4696/5000
# Processing batch 4697/5000
# Processing batch 4698/5000
# Processing batch 4699/5000
# Processing batch 4700/5000
# Processing batch 4701/5000
# Processing batch 4702/5000
# Processing batch 4703/5000
# Processing batch 4704/5000
# Processing batch 4705/5000
# Processing batch 4706/5000
# Processing batch 4707/5000
# Processing batch 4708/5000
# Processing batch 4709/5000
# Processing batch 4710/5000
# Processing batch 4711/5000
# Processing batch 4712/5000
# Processing batch 4713/5000
# Processing batch 4714/5000
# Processing batch 4715/5000
# Processing batch 4716/5000
# Processing batch 4717/5000
# Processing batch 4718/5000
# Processing batch 4719/5000
# Processing batch 4720/5000
# Processing batch 4721/5000
# Processing batch 4722/5000
# Processing batch 4723/5000
# Processing batch 4724/5000
# Processing batch 4725/5000
# Processing batch 4726/5000
# Processing batch 4727/5000
# Processing batch 4728/5000
# Processing batch 4729/5000
# Processing batch 4730/5000
# Processing batch 4731/5000
# Processing batch 4732/5000
# Processing batch 4733/5000
# Processing batch 4734/5000
# Processing batch 4735/5000
# Processing batch 4736/5000
# Processing batch 4737/5000
# Processing batch 4738/5000
# Processing batch 4739/5000
# Processing batch 4740/5000
# Processing batch 4741/5000
# Processing batch 4742/5000
# Processing batch 4743/5000
# Processing batch 4744/5000
# Processing batch 4745/5000
# Processing batch 4746/5000
# Processing batch 4747/5000
# Processing batch 4748/5000
# Processing batch 4749/5000
# Processing batch 4750/5000
# Processing batch 4751/5000
# Processing batch 4752/5000
# Processing batch 4753/5000
# Processing batch 4754/5000
# Processing batch 4755/5000
# Processing batch 4756/5000
# Processing batch 4757/5000
# Processing batch 4758/5000
# Processing batch 4759/5000
# Processing batch 4760/5000
# Processing batch 4761/5000
# Processing batch 4762/5000
# Processing batch 4763/5000
# Processing batch 4764/5000
# Processing batch 4765/5000
# Processing batch 4766/5000
# Processing batch 4767/5000
# Processing batch 4768/5000
# Processing batch 4769/5000
# Processing batch 4770/5000
# Processing batch 4771/5000
# Processing batch 4772/5000
# Processing batch 4773/5000
# Processing batch 4774/5000
# Processing batch 4775/5000
# Processing batch 4776/5000
# Processing batch 4777/5000
# Processing batch 4778/5000
# Processing batch 4779/5000
# Processing batch 4780/5000
# Processing batch 4781/5000
# Processing batch 4782/5000
# Processing batch 4783/5000
# Processing batch 4784/5000
# Processing batch 4785/5000
# Processing batch 4786/5000
# Processing batch 4787/5000
# Processing batch 4788/5000
# Processing batch 4789/5000
# Processing batch 4790/5000
# Processing batch 4791/5000
# Processing batch 4792/5000
# Processing batch 4793/5000
# Processing batch 4794/5000
# Processing batch 4795/5000
# Processing batch 4796/5000
# Processing batch 4797/5000
# Processing batch 4798/5000
# Processing batch 4799/5000
# Processing batch 4800/5000
# Processing batch 4801/5000
# Processing batch 4802/5000
# Processing batch 4803/5000
# Processing batch 4804/5000
# Processing batch 4805/5000
# Processing batch 4806/5000
# Processing batch 4807/5000
# Processing batch 4808/5000
# Processing batch 4809/5000
# Processing batch 4810/5000
# Processing batch 4811/5000
# Processing batch 4812/5000
# Processing batch 4813/5000
# Processing batch 4814/5000
# Processing batch 4815/5000
# Processing batch 4816/5000
# Processing batch 4817/5000
# Processing batch 4818/5000
# Processing batch 4819/5000
# Processing batch 4820/5000
# Processing batch 4821/5000
# Processing batch 4822/5000
# Processing batch 4823/5000
# Processing batch 4824/5000
# Processing batch 4825/5000
# Processing batch 4826/5000
# Processing batch 4827/5000
# Processing batch 4828/5000
# Processing batch 4829/5000
# Processing batch 4830/5000
# Processing batch 4831/5000
# Processing batch 4832/5000
# Processing batch 4833/5000
# Processing batch 4834/5000
# Processing batch 4835/5000
# Processing batch 4836/5000
# Processing batch 4837/5000
# Processing batch 4838/5000
# Processing batch 4839/5000
# Processing batch 4840/5000
# Processing batch 4841/5000
# Processing batch 4842/5000
# Processing batch 4843/5000
# Processing batch 4844/5000
# Processing batch 4845/5000
# Processing batch 4846/5000
# Processing batch 4847/5000
# Processing batch 4848/5000
# Processing batch 4849/5000
# Processing batch 4850/5000
# Processing batch 4851/5000
# Processing batch 4852/5000
# Processing batch 4853/5000
# Processing batch 4854/5000
# Processing batch 4855/5000
# Processing batch 4856/5000
# Processing batch 4857/5000
# Processing batch 4858/5000
# Processing batch 4859/5000
# Processing batch 4860/5000
# Processing batch 4861/5000
# Processing batch 4862/5000
# Processing batch 4863/5000
# Processing batch 4864/5000
# Processing batch 4865/5000
# Processing batch 4866/5000
# Processing batch 4867/5000
# Processing batch 4868/5000
# Processing batch 4869/5000
# Processing batch 4870/5000
# Processing batch 4871/5000
# Processing batch 4872/5000
# Processing batch 4873/5000
# Processing batch 4874/5000
# Processing batch 4875/5000
# Processing batch 4876/5000
# Processing batch 4877/5000
# Processing batch 4878/5000
# Processing batch 4879/5000
# Processing batch 4880/5000
# Processing batch 4881/5000
# Processing batch 4882/5000
# Processing batch 4883/5000
# Processing batch 4884/5000
# Processing batch 4885/5000
# Processing batch 4886/5000
# Processing batch 4887/5000
# Processing batch 4888/5000
# Processing batch 4889/5000
# Processing batch 4890/5000
# Processing batch 4891/5000
# Processing batch 4892/5000
# Processing batch 4893/5000
# Processing batch 4894/5000
# Processing batch 4895/5000
# Processing batch 4896/5000
# Processing batch 4897/5000
# Processing batch 4898/5000
# Processing batch 4899/5000
# Processing batch 4900/5000
# Processing batch 4901/5000
# Processing batch 4902/5000
# Processing batch 4903/5000
# Processing batch 4904/5000
# Processing batch 4905/5000
# Processing batch 4906/5000
# Processing batch 4907/5000
# Processing batch 4908/5000
# Processing batch 4909/5000
# Processing batch 4910/5000
# Processing batch 4911/5000
# Processing batch 4912/5000
# Processing batch 4913/5000
# Processing batch 4914/5000
# Processing batch 4915/5000
# Processing batch 4916/5000
# Processing batch 4917/5000
# Processing batch 4918/5000
# Processing batch 4919/5000
# Processing batch 4920/5000
# Processing batch 4921/5000
# Processing batch 4922/5000
# Processing batch 4923/5000
# Processing batch 4924/5000
# Processing batch 4925/5000
# Processing batch 4926/5000
# Processing batch 4927/5000
# Processing batch 4928/5000
# Processing batch 4929/5000
# Processing batch 4930/5000
# Processing batch 4931/5000
# Processing batch 4932/5000
# Processing batch 4933/5000
# Processing batch 4934/5000
# Processing batch 4935/5000
# Processing batch 4936/5000
# Processing batch 4937/5000
# Processing batch 4938/5000
# Processing batch 4939/5000
# Processing batch 4940/5000
# Processing batch 4941/5000
# Processing batch 4942/5000
# Processing batch 4943/5000
# Processing batch 4944/5000
# Processing batch 4945/5000
# Processing batch 4946/5000
# Processing batch 4947/5000
# Processing batch 4948/5000
# Processing batch 4949/5000
# Processing batch 4950/5000
# Processing batch 4951/5000
# Processing batch 4952/5000
# Processing batch 4953/5000
# Processing batch 4954/5000
# Processing batch 4955/5000
# Processing batch 4956/5000
# Processing batch 4957/5000
# Processing batch 4958/5000
# Processing batch 4959/5000
# Processing batch 4960/5000
# Processing batch 4961/5000
# Processing batch 4962/5000
# Processing batch 4963/5000
# Processing batch 4964/5000
# Processing batch 4965/5000
# Processing batch 4966/5000
# Processing batch 4967/5000
# Processing batch 4968/5000
# Processing batch 4969/5000
# Processing batch 4970/5000
# Processing batch 4971/5000
# Processing batch 4972/5000
# Processing batch 4973/5000
# Processing batch 4974/5000
# Processing batch 4975/5000
# Processing batch 4976/5000
# Processing batch 4977/5000
# Processing batch 4978/5000
# Processing batch 4979/5000
# Processing batch 4980/5000
# Processing batch 4981/5000
# Processing batch 4982/5000
# Processing batch 4983/5000
# Processing batch 4984/5000
# Processing batch 4985/5000
# Processing batch 4986/5000
# Processing batch 4987/5000
# Processing batch 4988/5000
# Processing batch 4989/5000
# Processing batch 4990/5000
# Processing batch 4991/5000
# Processing batch 4992/5000
# Processing batch 4993/5000
# Processing batch 4994/5000
# Processing batch 4995/5000
# Processing batch 4996/5000
# Processing batch 4997/5000
# Processing batch 4998/5000
# Processing batch 4999/5000
# Processing batch 5000/5000
# Length of all_labels: 100109, Length of all_preds: 100109
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 evaluate(model, val_dataloader, device)
#
# Cell In[16], line 37, in evaluate(model, val_dataloader, device)
#      35 # Calculate and print classification metrics
#      36 accuracy = accuracy_score(all_labels, all_preds)
# ---> 37 report = classification_report(all_labels, all_preds, target_names=["not humorous", "humorous"])
#      39 print(f"\nAccuracy: {accuracy:.4f}")
#      40 print("\nClassification Report:")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\metrics\_classification.py:2648, in classification_report(y_true, y_pred, labels, target_names, sample_weight, digits, output_dict, zero_division)
#    2642         warnings.warn(
#    2643             "labels size, {0}, does not match size of target_names, {1}".format(
#    2644                 len(labels), len(target_names)
#    2645             )
#    2646         )
#    2647     else:
# -> 2648         raise ValueError(
#    2649             "Number of classes, {0}, does not match size of "
#    2650             "target_names, {1}. Try specifying the labels "
#    2651             "parameter".format(len(labels), len(target_names))
#    2652         )
#    2653 if target_names is None:
#    2654     target_names = ["%s" % l for l in labels]
#
# ValueError: Number of classes, 3, does not match size of target_names, 2. Try specifying the labels parameter
